# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import io as io
import math
import copy
import scipy.signal as signal
import pyridoxine.plt as rxplt
import pyridoxine.utility as rxutil

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 6.2
# Extend your 1-d finite-volume solver for advection (from Exercise 5.1) to solve Burgers' equation. Your will need to change the Riemann solver and use the local velocity in the construction of the interface states. Run the examples shown in Figures 6.4 and 6.5.

# %%
class Limiters:
    """All sorts of limtiers & return partial a / partial x"""
    
    
    def __init__(self):
        
        pass
        
    @classmethod    
    def given_data(cls, a, dx):
        """Overload constructor with given data"""
        
        self.update_data(a, dx)
    
    def update(self, a, dx):
        """Update data and compute common expressions"""
        
        self.a = a
        self.dx = dx
        self.a_left_value = np.roll(self.a, 1)
        self.a_right_value = np.roll(self.a, -1)
        self.papx_i_L = (self.a - self.a_left_value) / self.dx
        self.papx_i_R = (self.a_right_value - self.a) / self.dx
        self.papx_i_RL = \
            (self.a_right_value - self.a_left_value) / (2 * self.dx)
        self.papx_i = np.zeros(len(a))
        
    def _minmod(self, a, b):
        """Choose the smaller one from |a| & |b| if they have the same sign"""
        
        if (abs(a) < abs(b)) and (a*b > 0.0):
            return a
        elif (abs(b) < abs(a)) and (a*b > 0.0):
            return b
        else:
            return 0.0
        """Another version using ternary statement
        return 0.0 \
            if a*b < 0.0 \
            else \
                (a if abs(a) < abs(b) else b)                
        """
    
    def _maxmod(self, a, b):
        """Choose the larger one from |a| & |b| if they have the same sign"""
        
        if (abs(a) > abs(b)) and (a*b > 0.0):
            return a
        elif (abs(b) > abs(a)) and (a*b > 0.0):
            return b
        else:
            return 0.0
        
    def unlimit(self, a=None, dx=None):
        """No limiting, equivalent to central-difference"""
        
        if a is not None or dx is not None:
            self.update(a, dx)
            
        return self.papx_i_RL
    
    
    def minmod(self, a=None, dx=None):
        """Minmod method -- abandon steeper slope"""
        
        if a is not None or dx is not None:
            self.update(a, dx)
            
        for i in range(len(self.a)):
            self.papx_i[i] = self._minmod(self.papx_i_L[i], self.papx_i_R[i])
            
        return self.papx_i

    def MClimiter(self, a=None, dx=None):
        """MC limiter -- minmod with central-difference"""
        
        if a is not None or dx is not None:
            self.update(a, dx)        
        
        for i in range(len(self.a)):
            self.papx_i[i] = self._minmod(self._minmod(2*self.papx_i_L[i],
                                                       2*self.papx_i_R[i]),
                                          self.papx_i_RL[i])
        
        return self.papx_i

    def piecewise_constant(self, a=None, dx=None):
        """Piecewise Constant -- equivalent to non-limiting / godunov"""
        
        if a is not None or dx is not None:
            self.update(a, dx)
            
        return np.zeros(len(a))

    def superbee(self, a=None, dx=None):
        """SuperBee -- softening minmod"""
        
        if a is not None or dx is not None:
            self.update(a, dx)
        
        for i in range(len(a)):
            papx_i_A = self._minmod(self.papx_i_R[i], 2*self.papx_i_L[i])
            papx_i_B = self._minmod(self.papx_i_L[i], 2*self.papx_i_R[i])
            self.papx_i[i] = self._maxmod(papx_i_A, papx_i_B)
            
        return self.papx_i

class Profile1D:
    """Create a profile in 1D"""
    
    def __init__(self, N, shape, Nghost, BCs, xmin=0.0, xmax=1.0):
        
        # N = the # of finite-volume cells, default x belongs to [0,1]        
        self.x = (np.arange(N+2*Nghost)+0.5-Nghost) / N
        self.x = self.x * (xmax-xmin) + xmin
        self.dx = (xmax-xmin) / N
        self.t = 0.0
        self.a = np.zeros(N+2*Nghost)
        self.u = np.zeros(N+2*Nghost)
        self.Nghost = Nghost
        self.shape = shape
        
        if shape == "Gaussian":
            self.a = signal.gaussian(N+2*Nghost, std=int(N/6))
        elif shape == "top-hat":
            index = np.logical_and(self.x >= 1./3., self.x <= 2./3.)
            self.a[index] = 1.0
        elif shape == "rarefaction":
            self.a[:] = 1.0
            self.a[self.x > 0.5] = 2.0
        elif shape == "sine":
            self.a[:] = 1.0
            index = np.logical_and(self.x >= 0.333, self.x <= 0.666)
            self.a[index] += \
                0.5*np.sin(2.0*math.pi*(self.x[index]-0.333)/0.333)
        else:
            print("Unrecognized shape")
        
        self.BCs = BCs
        self.apply_BCs()
        
    def apply_BCs(self):
        """Apply boundary conditions"""
        
        if self.BCs == "periodic":
            self.a[            :self.Nghost] = \
                                        self.a[-2*self.Nghost:-self.Nghost ]
            self.a[-self.Nghost:           ] = \
                                        self.a[self.Nghost   :2*self.Nghost]
            if hasattr(self.u, "__len__"):
                self.u[            :self.Nghost] = \
                                        self.u[-2*self.Nghost:-self.Nghost ]
                self.u[-self.Nghost:           ] = \
                                        self.u[self.Nghost   :2*self.Nghost]
        elif self.BCs == "outflow":
            self.a[            :self.Nghost] = self.a[self.Nghost]
            self.a[-self.Nghost:           ] = self.a[-self.Nghost-1]
            if hasattr(self.u, "__len__"):
                self.u[            :self.Nghost] = self.u[self.Nghost]
                self.u[-self.Nghost:           ] = self.u[-self.Nghost-1]

# %%
def BurgersEq():
        
    def onestep(pf, C):
        """Forward the profile one step"""
        
        u_left_value = np.roll(pf.u, 1)
        u_right_value = np.roll(pf.u, -1)
        pupx_i = Limiters().MClimiter(pf.u, pf.dx)
        
        #
        #  --+-----------------+------------------+
        #     ^       i       ^ ^        i+1
        #     ur(i)     ul(i+1) ur(i+1)
        #
        
        u_interface_left = u_left_value + 0.5*pf.dx \
            * (1-pf.dt/pf.dx*u_left_value)*np.roll(pupx_i, 1)
        u_interface_right = pf.u - 0.5*pf.dx * (1+pf.dt/pf.dx*pf.u)*pupx_i
        
        # Now solve Riemann problem
        S = 0.5 * (u_interface_left+u_interface_right)
        u_shock = np.where(S > 0.0, 
                           u_interface_left, u_interface_right)
        u_shock = np.where(S == 0.0, 0.0, u_shock)

        u_rare = np.where(u_interface_left > 0.0, 
                          u_interface_left, 0.0)
        u_rare = np.where(u_interface_right < 0.0,
                          u_interface_right, u_rare)
        u_flux = np.where(u_interface_left > u_interface_right,
                          u_shock, u_rare)
        #Tracer()() #this one triggers the debugger
        f_left = 0.5 * u_flux * u_flux
        f_right = np.roll(f_left, -1)
        pf.u = pf.u + pf.dt/pf.dx * (f_left-f_right)
        pf.apply_BCs()

    def update(pf, tlim, C):
        """Update a profile till t=tlim"""

        pf.dt = C * pf.dx / max(abs(pf.u))
        #Tracer()() #this one triggers the debugger
        while pf.t + pf.dt < tlim:
            onestep(pf, C)
            pf.t += pf.dt
            pf.dt = C * pf.dx / max(abs(pf.u))
        pf.dt = tlim - pf.t
        onestep(pf, C)        
                
    def compare(N, shape, BCs, tlim):
        """Compare simple simulations"""
        plt.rcParams.update(rxplt.plt_params("medium"))
        fig = plt.figure(1)
        ax = fig.add_subplot(111)
        C = 0.8
        
        for temp_tlim in np.linspace(0.0, tlim, 11):
            pf = Profile1D(N, shape, 2, BCs)
            pf.u = pf.a
            update(pf, temp_tlim, C)
            ls = '-' if temp_tlim != 0.0 else ':'
            co = str(0.85-0.84*temp_tlim/tlim) if temp_tlim != 0.0 else '0'
            ax.plot(pf.x, pf.u, label=shape, lw=1, linestyle=ls,
                    color=co)

        ax.set_xlim([0.0, 1.0])
        plt.show()
        plt.close("all")
        
    compare(256, "rarefaction", "outflow", 0.2)
    compare(256, "sine", "periodic", 0.2)

BurgersEq()

# %%
def BurgersEq_mdf():
    """Modified Code for Burger's Equation solver
        Now we modify the Burgers' Equation to
        u_t + u^2 u_x = 0,
        and try to solve it.
    """
        
    def onestep(pf, C):
        """Forward the profile one step"""
        
        u_left_value = np.roll(pf.u, 1)
        u_right_value = np.roll(pf.u, -1)
        if pf.shape == "rarefaction":
            pupx_i = Limiters().MClimiter(pf.u, pf.dx)
        if pf.shape == "sine":
            pupx_i = Limiters().unlimit(pf.u, pf.dx)
        
        #
        #  --+-----------------+------------------+
        #     ^       i       ^ ^        i+1
        #     ur(i)     ul(i+1) ur(i+1)
        #
        
        u_interface_left = u_left_value + 0.5*pf.dx \
            * (1-pf.dt/pf.dx*u_left_value**2)*np.roll(pupx_i, 1)
        u_interface_right = pf.u - 0.5*pf.dx * (1+pf.dt/pf.dx*pf.u**2)*pupx_i
        
        # Now solve Riemann problem
        S = (u_interface_left**2 + u_interface_left*u_interface_right + u_interface_right**2) / 3
        u_shock = np.where(S > 0.0, 
                           u_interface_left, u_interface_right)
        u_shock = np.where(S == 0.0, 0.0, u_shock)

        u_rare = np.where(u_interface_left > 0.0, 
                          u_interface_left, 0.0)
        u_rare = np.where(u_interface_right < 0.0,
                          u_interface_right, u_rare)
        u_flux = np.where(u_interface_left > u_interface_right,
                          u_shock, u_rare)
        #Tracer()() #this one triggers the debugger
        f_left = u_flux**3 / 3
        f_right = np.roll(f_left, -1)
        pf.u = pf.u + pf.dt/pf.dx * (f_left-f_right)
        pf.apply_BCs()

    def update(pf, tlim, C):
        """Update a profile till t=tlim"""

        pf.dt = C * pf.dx / max(abs(pf.u))
        #Tracer()() #this one triggers the debugger
        while pf.t + pf.dt < tlim:
            onestep(pf, C)
            pf.t += pf.dt
            pf.dt = C * pf.dx / max(abs(pf.u))
        pf.dt = tlim - pf.t
        onestep(pf, C)        
                
    def compare(N, shape, BCs, tlim):
        """Compare simple simulations"""
        
        fig, ax = plt.subplots()
        C = 0.8
        
        for temp_tlim in np.linspace(0.0, tlim, 11):
            pf = Profile1D(N, shape, 2, BCs)
            pf.u = pf.a
            update(pf, temp_tlim, C)
            ls = '-' if temp_tlim != 0.0 else ':'
            co = str(0.85-0.84*temp_tlim/tlim) if temp_tlim != 0.0 else '0'
            ax.plot(pf.x, pf.u, label=shape, lw=1, linestyle=ls,
                    color=co)

        ax.set_xlim([0.0, 1.0])
        ax.set_xlabel(r"$x$"); ax.set_ylabel(r"$u$")
        plt.show()
        
    #compare(512, "rarefaction", "outflow", 0.1)
    compare(1024, "sine", "periodic", 0.05)

BurgersEq_mdf()

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 7.1
# Show that the Euler equations in primitive form can be written as
# $$q_t + A(q) q_x = 0$$
# where
# $$ q = \begin{pmatrix}
# \rho \\
# u \\
# p
# \end{pmatrix}\ \ \ \ \
# A(q) = \begin{pmatrix}
# u & \rho      & 0      \\
# 0 &  u        & 1/\rho \\
# 0 &  \gamma p & u
# \end{pmatrix}
# $$

# %% [markdown]
# First, we need to derive the primitive form of Euler equations. Originally,
# \begin{align}
# \frac{\partial \rho}{\partial t} + \frac{\partial (\rho u)}{\partial x} &= 0, \\
# \frac{\partial(\rho u)}{\partial t} + \frac{\partial (\rho uu + p)}{\partial x} &= 0, \\
# \frac{\partial(\rho E)}{\partial t} + \frac{\partial(\rho u E + u p)}{\partial x} &= 0.
# \end{align}
# The continuity equation (1st one) is already what we want and can be used to transform the second one
#
# $$\frac{\partial(\rho u)}{\partial t} + \frac{\partial (\rho uu + p)}{\partial x} \Rightarrow \frac{\partial u}{\partial t} + u\frac{\partial u}{\partial x} + \frac{1}{\rho} \frac{\partial p}{\partial x}= 0.$$
#
# Then, note that
# $$\rho E = \frac{p}{\gamma-1} + \frac{1}{2}\rho u^2, $$
# which connects the conservative variables to the primitive variables. The energy equation now is
# \begin{align}
# \frac{\partial\left(\frac{p}{\gamma-1} + \frac{1}{2}\rho u^2\right)}{\partial t} + \frac{\partial\left[u\left(\frac{p}{\gamma-1} + \frac{1}{2}\rho u^2\right)\right]}{\partial x}  + \frac{\partial(u p)}{\partial x} &= 0, \\
# \frac{1}{\gamma-1}\frac{\partial p}{\partial t} + \rho u \frac{\partial u}{\partial t} + \frac{u^2}{2}\frac{\partial \rho}{\partial t} + \left(\frac{p}{\gamma-1} + \frac{1}{2}\rho u^2\right)\frac{\partial u}{\partial x} + u \frac{\partial\left(\frac{p}{\gamma-1} + \frac{1}{2}\rho u^2\right)}{\partial x} + \frac{\partial (up)}{\partial x} &= 0, \\
# \frac{1}{\gamma-1}\frac{\partial p}{\partial t} + \rho u \left(- u\frac{\partial u}{\partial x} - \frac{1}{\rho} \frac{\partial p}{\partial x}\right) + \frac{u^2}{2}\left(-\frac{\partial (\rho u)}{\partial x}\right) + \left(\frac{p}{\gamma-1} + \frac{1}{2}\rho u^2\right)\frac{\partial u}{\partial x} + u \frac{\partial\left(\frac{p}{\gamma-1} + \frac{1}{2}\rho u^2\right)}{\partial x} + \frac{\partial (up)}{\partial x} &= 0, \\
# \frac{1}{\gamma-1}\frac{\partial p}{\partial t} - \rho u^2 \frac{\partial u}{\partial x} \underline{- u \frac{\partial p}{\partial x}} + \frac{u^2}{2}\left(-\frac{\partial (\rho u)}{\partial x}\right) + \left(\frac{p}{\gamma-1} + \frac{1}{2}\rho u^2\right)\frac{\partial u}{\partial x} + u \frac{\partial\left(\frac{p}{\gamma-1} + \frac{1}{2}\rho u^2\right)}{\partial x}\underline{+ u\frac{\partial p}{\partial x}} + p\frac{\partial u}{\partial x} &= 0, \\
#  \frac{1}{\gamma-1}\frac{\partial p}{\partial t} \underline{-\left[\rho u^2 \frac{\partial u}{\partial x} - \frac{u^2}{2} \frac{\partial (\rho u)}{\partial x}\right]} + \frac{p}{\gamma-1}\frac{\partial u}{\partial x} \underline{+ \left[\frac{1}{2}\rho u^2\frac{\partial u}{\partial x}\right]} + \frac{u}{\gamma-1}\frac{\partial p}{\partial x} \underline{+ \left[u\frac{\partial \left(\frac{1}{2}\rho u^2\right)}{\partial x}\right]} + p\frac{\partial u}{\partial x} &= 0, \\
# \frac{\partial p}{\partial t} + p\frac{\partial u}{\partial x} + u\frac{\partial p}{\partial x} + p(\gamma -1)\frac{\partial u}{\partial x} &= 0, \\
# \Longrightarrow \frac{\partial p}{\partial t}+ u\frac{\partial p}{\partial x} + p\gamma \frac{\partial u}{\partial x} &= 0,
# \end{align}
# where the underline parts eliminate each other.
# To summarize the equations,
# \begin{align}
# \frac{\partial \rho}{\partial t} &+ u\frac{\partial \rho}{\partial x} + \rho\frac{\partial u}{\partial x} + 0\quad  &= 0, \\
# \frac{\partial u}{\partial t} &+ 0\quad + u\frac{\partial u}{\partial x} + \frac{1}{\rho} \frac{\partial p}{\partial x} &= 0, \\
# \frac{\partial p}{\partial t} &+ 0\quad + p\gamma \frac{\partial u}{\partial x} + u\frac{\partial p}{\partial x} &= 0.
# \end{align}
# In matrix form, we got
# $$
# \begin{pmatrix}
# \rho \\
# u \\
# p
# \end{pmatrix}_t +
# \begin{pmatrix}
# u & \rho      & 0      \\
# 0 &  u        & 1/\rho \\
# 0 &  \gamma p & u
# \end{pmatrix}
# \begin{pmatrix}
# \rho \\
# u \\
# p
# \end{pmatrix}_x = 0\ \ \Longrightarrow\ \ q_t + A(q) q_x = 0
# $$

# %% [markdown]
# ### Exercise 7.2
# Show that the eigenvalues of A are $\lambda^{(-)}=u-c$, $\lambda^{0}=0$, $\lambda^{(+)}=u+c$.

# %% [markdown]
# Calculate $|A-\lambda I| = 0$,
# $$
# \begin{pmatrix}
# u-\lambda & \rho        & 0         \\
# 0         &  u-\lambda  & 1/\rho    \\
# 0         &  \gamma p   & u-\lambda
# \end{pmatrix} = 0 \Longrightarrow = (u-\lambda)^3 - (u-\lambda)\frac{\gamma p}{\rho} = 0\ \ \Longrightarrow\ \ (u-\lambda)(u-\sqrt{\frac{\gamma p}{\rho}})(u+\sqrt{\frac{\gamma p}{\rho}}) = 0
# $$
#
# It's easy to see the solution: $\lambda^{(-)}=u-c$, $\lambda^{0}=0$, $\lambda^{(+)}=u+c$, where $c$ is the sound speed $\sqrt{\gamma p / \rho}$.

# %% [markdown]
# Note that both the conserved Jacobian matrix, $A(U)$, and the primitive variable matrix, $A(q)$, have the same eigenvalues, since they represent the same physics.
